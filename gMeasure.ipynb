# %%
import pandas as pd
import matplotlib as mp
import numpy as np

# %%
df=pd.read_csv("gOnFlatTable/Raw Data.csv")

# %%
df.describe()
# Out:
#          Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# count  793.000000              793.000000              793.000000
# mean     1.022993                0.014332               -0.081539
# std      0.575091                0.017533                0.018684
# min      0.028789               -0.040050               -0.144000
# 25%      0.525890                0.003000               -0.093000
# 50%      1.022992                0.013950               -0.081000
# 75%      1.520094                0.025950               -0.069000
# max      2.017196                0.073950               -0.024000
#
#        Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# count              793.000000                     793.000000
# mean                 9.846035                       9.846417
# std                  0.025284                       0.025280
# min                  9.777000                       9.777190
# 25%                  9.826950                       9.827535
# 50%                  9.847051                       9.847284
# 75%                  9.862950                       9.863277
# max                  9.922951                       9.923191

# %%
df.plot(x="Time (s)",title="Acceleration vs time",style='o-',ms=4,mfc='none');

# %%
df.hist("Absolute acceleration (m/s^2)",bins=10,range=(9.6,10));

# %%
plt=df.hist("Absolute acceleration (m/s^2)",bins=40,range=(9.6,10));

# %%
df.hist("Absolute acceleration (m/s^2)",bins=80,range=(9.6,10));

# %%
df.hist("Absolute acceleration (m/s^2)",bins=800,range=(9.6,10));

# %%
mean=np.mean(df["Absolute acceleration (m/s^2)"])
err_mean=np.std(df["Absolute acceleration (m/s^2)"],ddof=1)/np.sqrt(len(df["Absolute acceleration (m/s^2)"]))
print("acceleration=%3.3f ± %3.3f m/s^2"%(mean,err_mean))
# Out:
# acceleration=9.846 ± 0.001 m/s^2
