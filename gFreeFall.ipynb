# %%
import pandas as pd
import matplotlib as mp
import numpy as np

# %%
df=pd.read_csv("FreeFall_59cm/Raw Data.csv")

# %%
df.describe()
# Out:
#          Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# count  792.000000              792.000000              792.000000
# mean     1.019862               -0.388353                1.230398
# std      0.574326                1.133482               12.101947
# min      0.026983               -4.476000              -15.361951
# 25%      0.523422               -0.811050               -3.783000
# 50%      1.019863               -0.443025               -3.631950
# 75%      1.516301                0.004950                9.610538
# max      2.012743                9.610950               78.433952
#
#        Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# count              792.000000                     792.000000
# mean                 4.843378                      10.186684
# std                  6.363332                      10.463698
# min                -16.068001                       0.022998
# 25%                  0.034950                       9.311846
# ...

# %%
plt=df.plot(x="Time (s)",title="Acceleration vs time",style='o-',ms=4,mfc='none',grid=True);
plt.set_ylabel("Absolute acceleration (m/s^2)");

# %%
df_fall=df.loc[(df['Absolute acceleration (m/s^2)']<10) & (df['Time (s)']<0.93)]

# %%
df_fall.describe()
# Out:
#          Time (s)  Acceleration x (m/s^2)  Acceleration y (m/s^2)  \
# count  347.000000              347.000000              347.000000
# mean     0.461289                0.020419                5.824838
# std      0.251833                0.238513                4.741761
# min      0.026983               -0.712050               -0.213000
# 25%      0.244137               -0.016050               -0.037950
# 50%      0.461289                0.007050                9.615001
# 75%      0.678443                0.059025                9.708975
# max      0.895595                2.169000                9.993000
#
#        Acceleration z (m/s^2)  Absolute acceleration (m/s^2)
# count              347.000000                     347.000000
# mean                 0.054121                       5.880256
# std                  0.258867                       4.686257
# min                 -1.690050                       0.022998
# 25%                  0.006000                       0.064709
# ...

# %%
plt=df_fall.plot(x="Time (s)",title="Acceleration vs time",style='o-',ms=4,mfc='none',grid=True);
plt.set_ylabel("Absolute acceleration (m/s^2)");

# %%
df_start_fall=df_fall.loc[(df['Time (s)']<0.6)]

# %%
plt=df_start_fall.plot(x="Time (s)",title="Acceleration vs time",style='o-',ms=4,mfc='none',grid=True)
plt.set_xlim(0.52,0.58)
plt.set_ylabel("Absolute acceleration (m/s^2)")
plt.set_xticks(np.arange(0.52, 0.58, 0.005));

# %%
df_end_fall=df_fall.loc[(df['Time (s)']>0.8) & (df['Time (s)']<0.9)]

# %%
plt=df_end_fall.plot(x="Time (s)",title="Acceleration vs time",style='o-',ms=4,mfc='none',grid=True)
plt.set_xlim(0.85,0.91)
plt.set_ylabel("Absolute acceleration (m/s^2)")
plt.set_xticks(np.arange(0.85, 0.91, 0.005));

# %%
t_fall=0.895-0.55
g=2*0.59/(t_fall**2)
print("g=%3.1f ± %3.1f m/s^2"%(g,g*0.05))
# Out:
# g=9.9 ± 0.5 m/s^2
